# %% [markdown]
# - title: cookie clicker
# - toc: true

# %% [markdown]
# body {
#     padding-top: 30px;
#     font-family: Comic Sans;
#     background-color: blue;
#     width: 500px;
#     margin: auto;
#     text-align: center;
# }
#
# p {
#     font-size: 20px;
#     color: white;
#     display: block;
#     margin: 5px;
# }
#
# #space {
#     margin: auto;
#     text-align:center;
#     padding-top: 20px;
#     margin-bottom: 5px;
#     font-size: 30px;
#     border:5px solid;
#     border-radius:10px;
#     background-color: green;
#     color: white;
#     width:389px;
#     height:60px;
# }
#
# table {
#     margin-top: 10px;
#     border: 2px solid;
#     border-radius: 5px;
# }
#
# td {
#     border:1px solid;
# }
#
# #numbers {
#     margin: auto;
#     text-align:center;
#     padding-top: 20px;
#     margin-bottom: 20px;
#     font-size: 30px;
#     border:5px solid;
#     border-radius:10px;
#     background-color:white;
#     width:200px;
#     height:60px;
# }
#
# #upgradeLevel {
#     margin: auto;
#     text-align:center;
#     padding-top: 20px;
#     margin-bottom: 20px;
#     font-size: 30px;
#     border:5px solid;
#     border-radius:10px;
#     background-color:pink;
#     width:300px;
#     height:50px;
# }

# %% [markdown]
# <html>
#     <head>
#         <script type="text/javascript" src="js/beancan.js"></script>
#         <title>do you like beans</title>
#         <link rel = "stylesheet" href = "style.css"/>
#     </head>
#
#     <body>
#         <div id = "space"></div>
#         <div id = "can of beans" onclick="beancansClick()">
#             <img src="https://www.shutterstock.com/image-vector/baked-beans-tin-package-design-3d-1438531064" width="200px"/>
#         </div>
#
#         <p>bean cans</p>
#
#         <div id = "numbers"></div>
#         <div id= "upgradeLevel"></div>
#
#         <p>instructions: click the beans i dont know how much more obvious it can get than that</p>
#         <p>im not sure why you would spend that much time on the game but if you click a lot you level up </p>
#
#         <table>
#             <tr>
#                 <td>name</td>
#                 <td>bean can amounts</td>
#                 <td>money</td>
#             </tr>
#
#             <tr>
#                 <td>level one</td>
#                 <td>more beans</td>
#                 <td>a number of beans idk</td>
#             </tr>
#
#             <tr>
#                 <td>level two</td>
#                 <td> more beans exponentially</td>
#                 <td>a lot of beans im not sure</td>
#             </tr>
#
#             <tr>
#                 <td>level three</td>
#                 <td> a great number of beans</td>
#                 <td>VERY many beans idk im not counting</td>
#             </tr>
#
#              <tr>
#                 <td>please seek help</td>
#                 <td> you clicked so much please</td>
#                 <td>i cant do this anymore</td>
#             </tr>
#
#         </table>
#     </body>
# </html>

# %%
var num = 0;

window.onload = function () {
        var name = prompt("what should your shop be called");
        
        var space = document.getElementById("space");
        
        space.innerHTML = name;
}

var beancan = document.getElementById("can of beans");

function beancansClick() { 
    num += 1;

    var numbers = document.getElementById("numbers");
    
    
    var upgradeLevel = document.getElementById("upgradeLevel");
    
    numbers.innerHTML = num;      
    if(num >= 15 ){
        num += 3;
        upgradeLevel.innerHTML = "level one";
    }


    if(num >= 100) {
        num += 10;
        upgradeLevel.innerHTML = "level two";
    }


    if(num >= 200) {
        num += 20;
        upgradeLevel.innerHTML = "level three";
    }

    
    if(num >= 500) {
        num += 100;
        upgradeLevel.innerHTML = "your commitment to this game is concerning and unecessary. please seek help.";
    }
}
